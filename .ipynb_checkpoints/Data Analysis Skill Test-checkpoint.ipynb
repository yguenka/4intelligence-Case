# %% [markdown]
# # Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
import statsmodels.api as sm
from fbprophet import Prophet
from pandas.plotting import lag_plot
import seaborn as sns
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.stattools import adfuller
# Out:
# Importing plotly failed. Interactive plots will not work.

# %% [markdown]
# # Case 1

# %% [markdown]
# ## Análise exploratória

# %%
df = pd.read_csv('TFP.csv')

# %%
df
# Out:
#     isocode  year    rtfpna
# 0       USA  1950  0.617148
# 1       USA  1951  0.629588
# 2       USA  1952  0.638451
# 3       USA  1953  0.651858
# 4       USA  1954  0.646179
# ..      ...   ...       ...
# 181     MEX  2007  1.013673
# 182     MEX  2008  0.991548
# 183     MEX  2009  0.915879
# 184     MEX  2010  0.941604
# 185     MEX  2011  0.955766
#
# [186 rows x 3 columns]

# %%
mask1 = df['isocode'] == 'USA'
mask2 = df['isocode'] == 'CAN'
mask3 = df['isocode'] == 'MEX'

# %%
df_usa = df[mask1].drop(columns=['isocode'])
df_can = df[mask2].drop(columns=['isocode'])
df_mex = df[mask3].drop(columns=['isocode'])

# %%
plt.plot(df_usa['year'], df_usa['rtfpna'], 'r-', df_can['year'], df_can['rtfpna'], 'blue', df_mex['year'], df_mex['rtfpna'], 'green')
plt.show()

# %% [markdown]
# <b>Podemos ver que  o México possui uma grande variação em relação ao Canadá que é uma versão mais "achatada" da curva do México. Já o dos Estados Unidos, podemos ver que a curva é crescente ao analisar individualmente.</b>

# %%
plt.figure(figsize=(8,5))
sns.distplot(df_usa['rtfpna'], color='red',label='USA')
sns.distplot(df_can['rtfpna'], color='blue',label='CAN')
sns.distplot(df_mex['rtfpna'], color='green',label='MEX')
plt.legend()
plt.title('Frequency distribution')
#plt.tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)
plt.show()

# %% [markdown]
# <b>É possível observar que há uma quantidade de frequência maior nos dados do Canadá em comparação aos demais países.</b>

# %% [markdown]
# ## Forecast - Individual

# %%
df_usa = df_usa.rename({'year':'ds','rtfpna':'y'},axis=1)
df_can = df_can.rename({'year':'ds','rtfpna':'y'},axis=1)
df_mex = df_mex.rename({'year':'ds','rtfpna':'y'},axis=1)

# %%
df_usa.ds = pd.to_datetime(df_usa.ds, format='%Y')
df_can.ds = pd.to_datetime(df_can.ds, format='%Y')
df_mex.ds = pd.to_datetime(df_mex.ds, format='%Y')

# %%
fig, ax = plt.subplots(1, 3, figsize=(12,4))
lag_plot(df_usa['y'], c='red', ax = ax[0])
lag_plot(df_can['y'], c='blue', ax = ax[1])
lag_plot(df_mex['y'], c='green', ax = ax[2])

# %% [markdown]
# <b>No lag plot, podemos verificar se existe uma relação entre o período anterior com o período seguinte.
#
# Podemos dizer que nos USA existe uma forte relação entre o período anterior com o período seguinte mais forte do que os demais países que estamos analisando.</b>

# %% [markdown]
# ### USA

# %%
fig, ax = plt.subplots(2, 1,figsize=(12,8))
plot_acf(x=df_usa.y, ax=ax[0])
plot_pacf(x=df_usa.y, ax=ax[1]);

# %% [markdown]
# <b>O "pirulito" de número 6 entra na faixa, então vamos adicionar o período de número 6 para realizar o forecast.</b>

# %% [markdown]
# Decomposing a time series into:
#
# - Mean
# - Trends
# - Seasonal Effects
# - Noise

# %%
res = sm.tsa.seasonal_decompose(df_usa['y'], period=6)
observed = res.observed
seasonal = res.seasonal
residual = res.resid
trend = res.trend

# %%
df_res = pd.DataFrame({"observed":observed,"trend":trend, "seasonal":seasonal,"residual":residual})
plt.figure(figsize=(16,8))

plt.subplot(411)
sns.lineplot(x=df_res.index, y='observed', data=df_res, color ='red')
plt.title('USA')
plt.tick_params(axis='y', which='both', bottom=False, top=False, labelleft=False)

plt.subplot(412)
sns.lineplot(x=df_res.index, y='trend', data=df_res, color ='red')
plt.tick_params(axis='y', which='both', bottom=False, top=False, labelleft=False)

plt.subplot(413)
sns.lineplot(x=df_res.index, y='seasonal', data=df_res, color ='red')
plt.tick_params(axis='y', which='both', bottom=False, top=False, labelleft=False)

plt.subplot(414)
sns.lineplot(x=df_res.index, y='residual', data=df_res, color ='red')
plt.tick_params(axis='y', which='both', bottom=False, top=False, labelleft=False)
plt.hlines(y=0,xmin=df_res.index.min(), xmax=df_res.index.max())
plt.show()

# %% [markdown]
# <b> Ao realizar a decomposição, podemos observar que a linha de observado e a linha de tendência possuem uma forte relação. No caso do gráfico de sazonalidade, podemos ver um certo padrão. Enquanto o residual, podemos ver que desde o início há uma certa variação nos valores, indicando o valor dos erros.

# %%
model = Prophet(changepoint_range=1)
model.fit(df_usa) #df_usa.iloc[30:,:]
future = model.make_future_dataframe(periods=10,freq='Y')
forecast_usa = model.predict(future)
forecast_plot = model.plot(forecast_usa)
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
forecast_usa
# Out:
#            ds     trend  yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 0  1950-01-01  0.151957    0.604520    0.631111     0.151957     0.151957
# 1  1951-01-01  0.159292    0.611806    0.639153     0.159292     0.159292
# 2  1952-01-01  0.166628    0.621200    0.647843     0.166628     0.166628
# 3  1953-01-01  0.173983    0.628563    0.655319     0.173983     0.173983
# 4  1954-01-01  0.181319    0.633516    0.660244     0.181319     0.181319
# ..        ...       ...         ...         ...          ...          ...
# 67 2016-12-31  0.586995    1.043587    1.075337     0.578769     0.593588
# 68 2017-12-31  0.592388    1.055784    1.090087     0.582156     0.601008
# 69 2018-12-31  0.597781    1.070142    1.105395     0.585204     0.608555
# 70 2019-12-31  0.603173    1.087328    1.124490     0.588444     0.616122
# 71 2020-12-31  0.608581    1.060389    1.102310     0.591390     0.624363
#
#     additive_terms  additive_terms_lower  additive_terms_upper    yearly  \
# 0         0.465383              0.465383              0.465383  0.465383
# 1         0.465568              0.465568              0.465568  0.465568
# 2         0.468251              0.468251              0.468251  0.468251
# 3         0.467702              0.467702              0.467702  0.467702
# 4         0.465383              0.465383              0.465383  0.465383
# ..             ...                   ...                   ...       ...
# 67        0.473422              0.473422              0.473422  0.473422
# 68        0.481063              0.481063              0.481063  0.481063
# 69        0.491157              0.491157              0.491157  0.491157
# 70        0.503678              0.503678              0.503678  0.503678
# 71        0.473422              0.473422              0.473422  0.473422
#
#     yearly_lower  yearly_upper  multiplicative_terms  \
# 0       0.465383      0.465383                   0.0
# 1       0.465568      0.465568                   0.0
# 2       0.468251      0.468251                   0.0
# 3       0.467702      0.467702                   0.0
# 4       0.465383      0.465383                   0.0
# ..           ...           ...                   ...
# 67      0.473422      0.473422                   0.0
# 68      0.481063      0.481063                   0.0
# 69      0.491157      0.491157                   0.0
# 70      0.503678      0.503678                   0.0
# 71      0.473422      0.473422                   0.0
#
#     multiplicative_terms_lower  multiplicative_terms_upper      yhat
# 0                          0.0                         0.0  0.617340
# 1                          0.0                         0.0  0.624861
# 2                          0.0                         0.0  0.634879
# 3                          0.0                         0.0  0.641685
# 4                          0.0                         0.0  0.646702
# ..                         ...                         ...       ...
# 67                         0.0                         0.0  1.060417
# 68                         0.0                         0.0  1.073451
# 69                         0.0                         0.0  1.088938
# 70                         0.0                         0.0  1.106851
# 71                         0.0                         0.0  1.082002
#
# [72 rows x 16 columns]

# %% [markdown]
# <b>Podemos analisar no forecast, uma tendência de variação de acordo com o gráfico, mas ao ver os valores de um ano pro outro, é possivel ver que a diferença entre os valores de 2019 e 2020 é de 0.026115.</b>

# %% [markdown]
# ### CAN

# %%
fig, ax = plt.subplots(2, 1,figsize=(12,8))
plot_acf(x=df_can.y, ax=ax[0])
plot_pacf(x=df_can.y, ax=ax[1]);

# %% [markdown]
# <b>No caso do Canadá, vamos utilizar o número 4 como período de forecast, pois o 'pirulito' de número quatro entrou na área.</b>

# %%
res = sm.tsa.seasonal_decompose(df_can['y'], period=4)
observed = res.observed
seasonal = res.seasonal
residual = res.resid
trend = res.trend

df_res = pd.DataFrame({"observed":observed,"trend":trend, "seasonal":seasonal,"residual":residual})
plt.figure(figsize=(16,8))

plt.subplot(411)
sns.lineplot(x=df_res.index, y='observed', data=df_res, color ='blue')
plt.title('CAN')
plt.tick_params(axis='y', which='both', bottom=False, top=False, labelleft=False)

plt.subplot(412)
sns.lineplot(x=df_res.index, y='trend', data=df_res, color ='blue')
plt.tick_params(axis='y', which='both', bottom=False, top=False, labelleft=False)

plt.subplot(413)
sns.lineplot(x=df_res.index, y='seasonal', data=df_res, color ='blue')
plt.tick_params(axis='y', which='both', bottom=False, top=False, labelleft=False)

plt.subplot(414)
sns.lineplot(x=df_res.index, y='residual', data=df_res, color ='blue')
plt.tick_params(axis='y', which='both', bottom=False, top=False, labelleft=False)
plt.hlines(y=0,xmin=df_res.index.min(), xmax=df_res.index.max())
plt.show()

# %% [markdown]
# <b>No caso do Canadá,a linha de tendência e a observada são bem similares apesar da variação e uma alta sazonalidade. Já no valor residual, podemos ver que há uma grande variação dos valores no início e nos demais anos estão com menos variação.</b>

# %%
model = Prophet(changepoint_range=1)
model.fit(df_can)
future = model.make_future_dataframe(periods=10,freq='Y')
forecast_can = model.predict(future)
forecast_plot = model.plot(forecast_can)
#components_plot_forecast = model.plot_components(forecast)
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
forecast_can
# Out:
#            ds     trend  yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 0  1950-01-01  0.365645    0.846879    0.908877     0.365645     0.365645
# 1  1951-01-01  0.373179    0.857451    0.916879     0.373179     0.373179
# 2  1952-01-01  0.380713    0.872796    0.932298     0.380713     0.380713
# 3  1953-01-01  0.388267    0.878908    0.938641     0.388267     0.388267
# 4  1954-01-01  0.395801    0.880966    0.938371     0.395801     0.395801
# ..        ...       ...         ...         ...          ...          ...
# 67 2016-12-31  0.404311    0.909060    0.967929     0.399751     0.408843
# 68 2017-12-31  0.398640    0.923404    0.985695     0.392713     0.404557
# 69 2018-12-31  0.392969    0.943114    1.006422     0.385495     0.400439
# 70 2019-12-31  0.387298    0.971081    1.034331     0.378398     0.396476
# 71 2020-12-31  0.381611    0.886006    0.948711     0.371210     0.392213
#
#     additive_terms  additive_terms_lower  additive_terms_upper    yearly  \
# 0         0.512591              0.512591              0.512591  0.512591
# 1         0.512818              0.512818              0.512818  0.512818
# 2         0.519804              0.519804              0.519804  0.519804
# 3         0.519123              0.519123              0.519123  0.519123
# 4         0.512591              0.512591              0.512591  0.512591
# ..             ...                   ...                   ...       ...
# 67        0.533534              0.533534              0.533534  0.533534
# 68        0.553984              0.553984              0.553984  0.553984
# 69        0.581117              0.581117              0.581117  0.581117
# 70        0.614884              0.614884              0.614884  0.614884
# 71        0.533534              0.533534              0.533534  0.533534
#
#     yearly_lower  yearly_upper  multiplicative_terms  \
# 0       0.512591      0.512591                   0.0
# 1       0.512818      0.512818                   0.0
# 2       0.519804      0.519804                   0.0
# 3       0.519123      0.519123                   0.0
# 4       0.512591      0.512591                   0.0
# ..           ...           ...                   ...
# 67      0.533534      0.533534                   0.0
# 68      0.553984      0.553984                   0.0
# 69      0.581117      0.581117                   0.0
# 70      0.614884      0.614884                   0.0
# 71      0.533534      0.533534                   0.0
#
#     multiplicative_terms_lower  multiplicative_terms_upper      yhat
# 0                          0.0                         0.0  0.878236
# 1                          0.0                         0.0  0.885997
# 2                          0.0                         0.0  0.900516
# 3                          0.0                         0.0  0.907390
# 4                          0.0                         0.0  0.908392
# ..                         ...                         ...       ...
# 67                         0.0                         0.0  0.937845
# 68                         0.0                         0.0  0.952624
# 69                         0.0                         0.0  0.974086
# 70                         0.0                         0.0  1.002181
# 71                         0.0                         0.0  0.915145
#
# [72 rows x 16 columns]

# %% [markdown]
# <b>Para o forecast, podemos ver no gráfico que há uma enorme variação, mas ao ver os valores de 2018, que foi de 0.974086 e de 2019 que foi de 1.002181, mostra que a variação não é tão drástica quanto aparente.</b>

# %% [markdown]
# ### MEX

# %%
fig, ax = plt.subplots(2, 1,figsize=(12,8))
plot_acf(x=df_mex.y, ax=ax[0])
plot_pacf(x=df_mex.y, ax=ax[1]);

# %% [markdown]
# <b>Para o México, vamos utilizar o número 5 como período de frequência para realizar o forecast.</b>

# %%
res = sm.tsa.seasonal_decompose(df_mex['y'], period=5)
observed = res.observed
seasonal = res.seasonal
residual = res.resid
trend = res.trend

df_res = pd.DataFrame({"observed":observed,"trend":trend, "seasonal":seasonal,"residual":residual})
plt.figure(figsize=(16,8))

plt.subplot(411)
sns.lineplot(x=df_res.index, y='observed', data=df_res, color ='green')
plt.title('MEX')
plt.tick_params(axis='y', which='both', bottom=False, top=False, labelleft=False)

plt.subplot(412)
sns.lineplot(x=df_res.index, y='trend', data=df_res, color ='green')
plt.tick_params(axis='y', which='both', bottom=False, top=False, labelleft=False)

plt.subplot(413)
sns.lineplot(x=df_res.index, y='seasonal', data=df_res, color ='green')
plt.tick_params(axis='y', which='both', bottom=False, top=False, labelleft=False)

plt.subplot(414)
sns.lineplot(x=df_res.index, y='residual', data=df_res, color ='green')
plt.tick_params(axis='y', which='both', bottom=False, top=False, labelleft=False)
plt.hlines(y=0,xmin=df_res.index.min(), xmax=df_res.index.max())
plt.show()

# %% [markdown]
# <b>O gráfico residual do México se parecem muito com o dos Estados Unidos, onde há uma grande variação entre os valores ao longo do período. Já os demais gráficos se parecem mais com o do Canadá, onde é uma curva crescente e decrescente ao longo dos anos.</b>

# %%
model = Prophet(changepoint_range=1)
model.fit(df_mex)
future = model.make_future_dataframe(periods=10,freq='Y')
forecast_mex = model.predict(future)
forecast_plot = model.plot(forecast_mex)
#components_plot_forecast = model.plot_components(forecast)
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
forecast_mex
# Out:
#            ds     trend  yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 0  1950-01-01  0.424600    0.783326    0.871629     0.424600     0.424600
# 1  1951-01-01  0.453215    0.817190    0.901808     0.453215     0.453215
# 2  1952-01-01  0.481830    0.857145    0.944919     0.481830     0.481830
# 3  1953-01-01  0.510523    0.875348    0.963275     0.510523     0.510523
# 4  1954-01-01  0.539137    0.899887    0.987501     0.539137     0.539137
# ..        ...       ...         ...         ...          ...          ...
# 67 2016-12-31  0.483786    0.871297    0.965244     0.465391     0.501758
# 68 2017-12-31  0.475738    0.891725    0.985319     0.452717     0.497976
# 69 2018-12-31  0.467691    0.912146    1.010647     0.439961     0.495819
# 70 2019-12-31  0.459643    0.943602    1.053514     0.425806     0.492675
# 71 2020-12-31  0.451573    0.825283    0.952909     0.411731     0.490888
#
#     additive_terms  additive_terms_lower  additive_terms_upper    yearly  \
# 0         0.403982              0.403982              0.403982  0.403982
# 1         0.406352              0.406352              0.406352  0.406352
# 2         0.416801              0.416801              0.416801  0.416801
# 3         0.409690              0.409690              0.409690  0.409690
# 4         0.403982              0.403982              0.403982  0.403982
# ..             ...                   ...                   ...       ...
# 67        0.435317              0.435317              0.435317  0.435317
# 68        0.461872              0.461872              0.461872  0.461872
# 69        0.496423              0.496423              0.496423  0.496423
# 70        0.538915              0.538915              0.538915  0.538915
# 71        0.435317              0.435317              0.435317  0.435317
#
#     yearly_lower  yearly_upper  multiplicative_terms  \
# 
   0.0
#
#     multiplicative_terms_lower  multiplicative_terms_upper      yhat
# 0                          0.0                         0.0  0.617340
# 1                          0.0                         0.0  0.624861
# 2                          0.0                         0.0  0.634879
# 3                          0.0                         0.0  0.641685
# 4                          0.0                         0.0  0.646702
# ..                         ...                         ...       ...
# 67                         0.0                         0.0  1.060417
# 68                         0.0                         0.0  1.073451
# 69                         0.0                         0.0  1.088938
# 70                         0.0                         0.0  1.106851
# 71                         0.0                         0.0  1.082002
#
# [72 rows x 16 columns]

# %%
fig= plt.subplots(figsize=(12,8))
plt.plot(forecast_usa.ds, forecast_usa.yhat, 'r-', forecast_can.ds, forecast_can.yhat, 'blue', forecast_mex.ds, forecast_mex.yhat, 'green')
plt.show()

# %% [markdown]
# # CASE 2

# %% [markdown]
# ## Evolução das exportações totais mensais e anuais totais do Brasil.

# %%
df = pd.read_csv('data_comexstat.csv', encoding='latin-1')
df['exp'] = df['tons'] * df['usd']

# %%
mask = df['type'] == 'Export'
df = df[mask]

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df['product'].unique()
# Out:
# array(['corn', 'soybean_meal', 'soybean_oil', 'soybeans', 'sugar',
#        'wheat'], dtype=object)

# %% [markdown]
# ### Total Mensal

# %%
mask1 = df['product'] == 'soybeans'
mask2 = df['product'] == 'soybean_oil'
mask3 = df['product'] == 'soybean_meal'

df_soybeans_month = df[mask1]
df_soybean_oil_month = df[mask2]
df_soybean_meal_month = df[mask3]

# %%
df_soybeans_month = df_soybeans_month.groupby('date')[['exp']].sum().reset_index()
df_soybean_oil_month = df_soybean_oil_month.groupby('date')[['exp']].sum().reset_index()
df_soybean_meal_month = df_soybean_meal_month.groupby('date')[['exp']].sum().reset_index()

# %%
fig, ax = plt.subplots(1, 3, figsize=(15,4))
ax[0].plot(df_soybeans_month['date'], df_soybeans_month['exp'], 'r-')
ax[0].legend(['Soybeans'])

ax[1].plot(df_soybean_oil_month['date'], df_soybean_oil_month['exp'], 'blue')
ax[1].legend(['Soybean Oil'])

ax[2].plot(df_soybean_meal_month['date'], df_soybean_meal_month['exp'], 'green')
ax[2].legend(['Soybean Meal'])
plt.show()

# %% [markdown]
# <b>Ao colocar os gráficos lado a lado, podemos ver que a escala dos produtos estão bem parecidas caso não tenha o cuidado para ver que no eixo-y há uma grande diferença na quantidade de soja e a farinha de soja.</b>

# %%
fig = plt.subplots(figsize=(12,5))
plt.plot(df_soybeans_month['date'], df_soybeans_month['exp'], 'r-', 
         df_soybean_oil_month['date'], df_soybean_oil_month['exp'], 
         'blue', df_soybean_meal_month['date'], df_soybean_meal_month['exp'], 'green', )
plt.show()

# %% [markdown]
# ### Total Anual

# %%
df = df.reset_index().drop(columns=['index'])

# %%
df
# Out:
#              date product state           country    type   route        tons  \
# 0      1997-01-01    corn    GO           Bolivia  Export  Ground       0.200
# 1      1997-01-01    corn    GO     United States  Export     Sea       3.488
# 2      1997-01-01    corn    MS          Paraguay  Export  Ground      40.000
# 3      1997-01-01    corn    PR       Netherlands  Export     Sea  170000.000
# 4      1997-01-01    corn    PR          Paraguay  Export  Ground     258.300
# ...           ...     ...   ...               ...     ...     ...         ...
# 105856 2019-12-01   wheat    PR     United States  Export     Sea       0.400
# 105857 2019-12-01   wheat    RS           Vietnam  Export     Sea   36698.000
# 105858 2019-12-01   wheat    SP           Ireland  Export     Sea       0.500
# 105859 2019-12-01   wheat    SP           Liberia  Export   Other       0.025
# 105860 2019-12-01   wheat    SP  Marshall Islands  Export   Other       0.010
#
#                usd           exp
# 0            180.0  3.600000e+01
# 1           5688.0  1.983974e+04
# 2          38700.0  1.548000e+06
# 3       20000000.0  3.400000e+12
# 4         386733.0  9.989313e+07
# ...            ...           ...
# 105856       400.0  1.600000e+02
# 105857   6963002.0  2.555282e+11
# 105858       477.0  2.385000e+02
# 105859        50.0  1.250000e+00
# 105860        85.0  8.500000e-01
#
# [105861 rows x 9 columns]

# %%
df['year'] = 0
for item in range(0, 105861):
    df['year'][item] = df['date'][item].year
# Out:
# C:\Users\yukar\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df
# Out:
#              date product state           country    type   route        tons  \
# 0      1997-01-01    corn    GO           Bolivia  Export  Ground       0.200
# 1      1997-01-01    corn    GO     United States  Export     Sea       3.488
# 2      1997-01-01    corn    MS          Paraguay  Export  Ground      40.000
# 3      1997-01-01    corn    PR       Netherlands  Export     Sea  170000.000
# 4      1997-01-01    corn    PR          Paraguay  Export  Ground     258.300
# ...           ...     ...   ...               ...     ...     ...         ...
# 105856 2019-12-01   wheat    PR     United States  Export     Sea       0.400
# 105857 2019-12-01   wheat    RS           Vietnam  Export     Sea   36698.000
# 105858 2019-12-01   wheat    SP           Ireland  Export     Sea       0.500
# 105859 2019-12-01   wheat    SP           Liberia  Export   Other       0.025
# 105860 2019-12-01   wheat    SP  Marshall Islands  Export   Other       0.010
#
#                usd           exp  year
# 0            180.0  3.600000e+01  1997
# 1           5688.0  1.983974e+04  1997
# 2          38700.0  1.548000e+06  1997
# 3       20000000.0  3.400000e+12  1997
# 4         386733.0  9.989313e+07  1997
# ...            ...           ...   ...
# 105856       400.0  1.600000e+02  2019
# 105857   6963002.0  2.555282e+11  2019
# 105858       477.0  2.385000e+02  2019
# 105859        50.0  1.250000e+00  2019
# 105860        85.0  8.500000e-01  2019
#
# [105861 rows x 10 columns]

# %%
mask1 = df['product'] == 'soybeans'
mask2 = df['product'] == 'soybean_oil'
mask3 = df['product'] == 'soybean_meal'

df_soybeans_year = df[mask1]
df_soybean_oil_year = df[mask2]
df_soybean_meal_year = df[mask3]

# %%
df_soybeans_year = df_soybeans_year.groupby('year')[['exp']].sum().reset_index()
df_soybean_oil_year = df_soybean_oil_year.groupby('year')[['exp']].sum().reset_index()
df_soybean_meal_year = df_soybean_meal_year.groupby('year')[['exp']].sum().reset_index()

# %%
fig, ax = plt.subplots(1, 3, figsize=(15,4))
ax[0].plot(df_soybeans_year['year'], df_soybeans_year['exp'], 'r-')
ax[0].legend(['Soybeans'])

ax[1].plot(df_soybean_oil_year['year'], df_soybean_oil_year['exp'], 'blue')
ax[1].legend(['Soybean Oil'])

ax[2].plot(df_soybean_meal_year['year'], df_soybean_meal_year['exp'], 'green')
ax[2].legend(['Soybean Meal'])
plt.show()

# %%
fig = plt.subplots(figsize=(12,5))
plt.plot(df_soybeans_year['year'], df_soybeans_year['exp'], 'r-', 
         df_soybean_oil_year['year'], df_soybean_oil_year['exp'], 'blue', 
         df_soybean_meal_year['year'], df_soybean_meal_year['exp'], 'green', )
plt.show()

# %% [markdown]
# ## Os 3 produtos mais importantes exportados pelo Brasil

# %%
mask_5 = (df['year'] <= 2019) & (df['year'] >= 2015)
df_5 = df[mask_5]

# %%
export = df_5.groupby('product')[['exp']].sum().reset_index().sort_values(by='exp', ascending=False)

# %%
export.head(3)
# Out:
#     product           exp
# 3  soybeans  5.836316e+16
# 0      corn  2.969254e+15
# 4     sugar  2.919607e+15

# %%
plt.figure(figsize=(8,5))
plt.barh(export['product'], export['exp'], color='blue')
plt.title('Products')
plt.show()

# %% [markdown]
# ## As principais rotas pelas quais o Brasil exporta 'milho' nos últimos anos. E as diferenças na importância relativa das rotas, dependendo do produto.

# %%
df = pd.read_csv('data_comexstat.csv', encoding='latin-1')
df['exp'] = df['tons'] * df['usd']

# %%
mask_corn = (df['type'] == 'Export') & (df['product'] == 'corn')
df_corn = df[mask_corn]

# %%
plt.figure(figsize=(8,5))
plt.hist(df_corn['route'], color='magenta')
plt.title('Frequency distribution')
plt.show()

# %%
mask_sugar = (df['type'] == 'Export') & (df['product'] == 'sugar')
df_sugar = df[mask_sugar]

mask_soybean_meal = (df['type'] == 'Export') & (df['product'] == 'soybean_meal')
df_soybean_meal = df[mask_soybean_meal]

mask_soybean_oil = (df['type'] == 'Export') & (df['product'] == 'soybean_oil')
df_soybean_oil = df[mask_soybean_oil]

mask_soybeans = (df['type'] == 'Export') & (df['product'] == 'soybeans')
df_soybeans = df[mask_soybeans]

mask_wheat = (df['type'] == 'Export') & (df['product'] == 'wheat')
df_wheat = df[mask_wheat]

# %%
fig, ax = plt.subplots(6,1, figsize=(15,10))
ax[0].hist(df_corn['route'], color='magenta')
ax[0].legend(['Corn'])

ax[1].hist(df_sugar['route'], color='blue')
ax[1].legend(['Sugar'])

ax[2].hist(df_soybean_meal['route'], color='green')
ax[2].legend(['Soybean Meal'])

ax[3].hist(df_soybean_oil['route'], color='black')
ax[3].legend(['Soybean Oil'])

ax[4].hist(df_soybeans['route'], color='yellow')
ax[4].legend(['Soybeans'])

ax[5].hist(df_wheat['route'], color='red')
ax[5].legend(['Wheat'])
plt.show()

# %% [markdown]
# ## Parceiros comerciais mais importantes para o Brasil em termos de 'milho' e 'açúcar' nos últimos 3 anos.

# %%
df = pd.read_csv('data_comexstat.csv', encoding='latin-1')
df['exp'] = df['tons'] * df['usd']

# %%
df['date'] = pd.to_datetime(df['date'])
df['year'] = 0
for item in range(0, 117965):
    df['year'][item] = df['date'][item].year
# Out:
# C:\Users\yukar\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
mask_corn = (df['type'] == 'Export') & (df['product'] == 'corn') & (df['year'] <= 2019) & (df['year'] >= 2017)
df_3years_corn = df[mask_corn]

mask_sugar = (df['type'] == 'Export') & (df['product'] == 'sugar' ) & (df['year'] <= 2019) & (df['year'] >= 2017)
df_3years_sugar = df[mask_sugar]

mask_3years = (df['type'] == 'Export') & (df['product'] == 'sugar' ) | (df['product'] == 'corn') & (df['year'] <= 2019) & (df['year'] >= 2017)
df_3years = df[mask_3years]

# %%
export_3years_corn = df_3years_corn.groupby('country')[['exp']].sum().reset_index().sort_values(by='exp', ascending=False).head(10)
export_3years_sugar = df_3years_sugar.groupby('country')[['exp']].sum().reset_index().sort_values(by='exp', ascending=False).head(10)
export_3years = df_3years.groupby('country')[['exp']].sum().reset_index().sort_values(by='exp', ascending=False).head(10)

# %%
fig, ax = plt.subplots(3, 1, figsize=(12, 10))
ax[0].barh(export_3years_corn['country'], export_3years_corn['exp'], color='yellow')
ax[0].set(title="Corn")

ax[1].barh(export_3years_sugar['country'], export_3years_sugar['exp'], color='magenta')
ax[1].set(title="Sugar")

ax[2].barh(export_3years['country'], export_3years['exp'], color='blue')
ax[2].set(title="Corn and Sugar")
plt.show()

# %% [markdown]
# ## Os 5 estados mais importantes em termos de exportação por produto

# %%
df = pd.read_csv('data_comexstat.csv', encoding='latin-1')
df['exp'] = df['tons'] * df['usd']

# %%
mask_ex = (df['type'] == 'Export')
exportation = df[mask_ex]

# %%
exportation = exportation.groupby(['product', 'state'])[['exp']].sum().reset_index().sort_values(by='exp', ascending=False)

# %%
mask_corn = (exportation['product'] == 'corn')
df_corn = exportation[mask_corn].head(5)

mask_sugar = (exportation['product'] == 'sugar')
df_sugar = exportation[mask_sugar].head(5)

mask_soybean_meal = (exportation['product'] == 'soybean_meal')
df_soybean_meal = exportation[mask_soybean_meal].head(5)

mask_soybean_oil = (exportation['product'] == 'soybean_oil')
df_soybean_oil = exportation[mask_soybean_oil].head(5)

mask_soybeans = (exportation['product'] == 'soybeans')
df_soybeans = exportation[mask_soybeans].head(5)

mask_wheat = (exportation['product'] == 'wheat')
df_wheat = exportation[mask_wheat].head(5)

# %%
df_wheat
# Out:
#     product state           exp
# 133   wheat    RS  1.164078e+14
# 130   wheat    PR  6.447771e+12
# 134   wheat    SC  1.163603e+12
# 135   wheat    SP  1.059066e+10
# 129   wheat    MS  1.276148e+08

# %%
fig, ax = plt.subplots(6, 1, figsize=(15,22))
ax[0].barh(df_corn['state'], df_corn['exp'], color='magenta')
ax[0].set(title='Corn')

ax[1].barh(df_sugar['state'], df_sugar['exp'], color='blue')
ax[1].set(title='Sugar')

ax[2].barh(df_soybean_meal['state'], df_soybean_meal['exp'], color='green')
ax[2].set(title='Soybean Meal')

ax[3].barh(df_soybean_oil['state'], df_soybean_oil['exp'], color='black')
ax[3].set(title='Soybean Oil')

ax[4].barh(df_soybeans['state'], df_soybeans['exp'], color='yellow')
ax[4].set(title='Soybeans')

ax[5].barh(df_wheat['state'], df_wheat['exp'], color='red')
ax[5].set(title='Wheat')
plt.show()

# %% [markdown]
# ## Forecast 11 anos do milho, soja e da farinha de milho.

# %%
df = pd.read_csv('data_comexstat.csv', encoding='latin-1')
df['exp'] = df['tons'] * df['usd']

# %%
df['date'] = pd.to_datetime(df['date'])
df['year'] = 0
for item in range(0, 117965):
    df['year'][item] = df['date'][item].year
# Out:
# C:\Users\yukar\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
mask_corn = (df['type'] == 'Export') & (df['product'] == 'corn')
mask_soybeans = (df['type'] == 'Export') & (df['product'] == 'soybeans')
mask_soybean_meal = (df['type'] == 'Export') & (df['product'] == 'soybean_meal')
df_corn = df[mask_corn]
df_soybeans = df[mask_soybeans]
df_soybean_meal = df[mask_soybean_meal]

# %%
df_corn = df_corn.rename({'year':'ds','exp':'y'},axis=1)
df_soybeans = df_soybeans.rename({'year':'ds','exp':'y'},axis=1)
df_soybean_meal = df_soybean_meal.rename({'year':'ds','exp':'y'},axis=1)

# %%
df_corn.ds = pd.to_datetime(df_corn.ds, format='%Y')
df_soybeans.ds = pd.to_datetime(df_soybeans.ds, format='%Y')
df_soybean_meal.ds = pd.to_datetime(df_soybean_meal.ds, format='%Y')

# %%
df_corn = df_corn.groupby('ds')[['y']].sum().reset_index()
df_soybeans = df_soybeans.groupby('ds')[['y']].sum().reset_index()
df_soybean_meal = df_soybean_meal.groupby('ds')[['y']].sum().reset_index()

# %%
plt.plot(df_corn['ds'], df_corn['y'], 'r-', 
         df_soybeans['ds'], df_soybeans['y'], 'blue', 
         df_soybean_meal['ds'], df_soybean_meal['y'], 'green')
plt.show()

# %%
fig, ax = plt.subplots(1, 3, figsize=(12,4))
lag_plot(df_corn['y'], c='red', ax = ax[0])
lag_plot(df_soybeans['y'], c='blue', ax = ax[1])
lag_plot(df_soybean_meal['y'], c='green', ax = ax[2])

# %% [markdown]
# ### Milho

# %%
fig, ax = plt.subplots(2, 1,figsize=(12,8))
plot_acf(x=df_corn.y, ax=ax[0])
plot_pacf(x=df_corn.y, ax=ax[1]);

# %%
res = sm.tsa.seasonal_decompose(df_corn['y'], period=2)
observed = res.observed
seasonal = res.seasonal
residual = res.resid
trend = res.trend


df_res = pd.DataFrame({"observed":observed,"trend":trend, "seasonal":seasonal,"residual":residual})
plt.figure(figsize=(16,8))

plt.subplot(411)
sns.lineplot(x=df_res.index, y='observed', data=df_res, color ='magenta')
plt.title('Corn')
plt.tick_params(axis='y', which='both', bottom=False, top=False, labelleft=False)

plt.subplot(412)
sns.lineplot(x=df_res.index, y='trend', data=df_res, color ='magenta')
plt.tick_params(axis='y', which='both', bottom=False, top=False, labelleft=False)

plt.subplot(413)
sns.lineplot(x=df_res.index, y='seasonal', data=df_res, color ='magenta')
plt.tick_params(axis='y', which='both', bottom=False, top=False, labelleft=False)

plt.subplot(414)
sns.lineplot(x=df_res.index, y='residual', data=df_res, color ='magenta')
plt.tick_params(axis='y', which='both', bottom=False, top=False, labelleft=False)
plt.hlines(y=0,xmin=df_res.index.min(), xmax=df_res.index.max())
plt.show()

# %%
model = Prophet()
model.fit(df_corn)
future = model.make_future_dataframe(periods=11, freq='Y')
forecast_corn = model.predict(future)
forecast_plot = model.plot(forecast_corn)
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 17.

# %%
forecast_corn
# Out:
#            ds         trend    yhat_lower    yhat_upper   trend_lower  \
# 0  1997-01-01 -1.403632e+14 -2.864664e+14 -9.974066e+12 -1.403632e+14
# 1  1998-01-01 -1.063571e+14 -2.546025e+14  2.891176e+13 -1.063571e+14
# 2  1999-01-01 -7.235095e+13 -2.175389e+14  5.367019e+13 -7.235095e+13
# 3  2000-01-01 -3.834482e+13 -1.969058e+14  8.624812e+13 -3.834482e+13
# 4  2001-01-01 -4.245522e+12 -1.525100e+14  1.352146e+14 -4.245522e+12
# 5  2002-01-01  2.976061e+13 -1.078464e+14  1.702096e+14  2.976061e+13
# 6  2003-01-01  6.376674e+13 -9.379261e+13  1.882464e+14  6.376674e+13
# 7  2004-01-01  9.777287e+13 -5.970232e+13  2.167358e+14  9.777287e+13
# 8  2005-01-01  1.318722e+14 -1.351600e+13  2.594737e+14  1.318722e+14
# 9  2006-01-01  1.658783e+14  2.421739e+13  3.106048e+14  1.658783e+14
# 10 2007-01-01  1.998844e+14  3.606307e+13  3.208527e+14  1.998844e+14
# 11 2008-01-01  2.338906e+14  7.410991e+13  3.637313e+14  2.338906e+14
# 12 2009-01-01  2.679899e+14  1.316827e+14  3.956784e+14  2.679899e+14
# 13 2010-01-01  3.019960e+14  1.530692e+14  4.423277e+14  3.019960e+14
# 26                         0.0                         0.0  6.829152e+14
# 27                         0.0                         0.0  6.977168e+14
# 28                         0.0                         0.0  7.811672e+14
# 29                         0.0                         0.0  8.014866e+14
# 30                         0.0                         0.0  8.190341e+14
# 31                         0.0                         0.0  8.338357e+14
# 32                         0.0                         0.0  9.172861e+14
# 33                         0.0                         0.0  9.376055e+14

# %% [markdown]
# ### Soja

# %%
fig, ax = plt.subplots(2, 1,figsize=(12,8))
plot_acf(x=df_soybeans.y, ax=ax[0])
plot_pacf(x=df_soybeans.y, ax=ax[1]);
# Out:
# C:\Users\yukar\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1406: RuntimeWarning:
#
# invalid value encountered in sqrt

# %%
res = sm.tsa.seasonal_decompose(df_corn['y'], period=3)
observed = res.observed
seasonal = res.seasonal
residual = res.resid
trend = res.trend


df_res = pd.DataFrame({"observed":observed,"trend":trend, "seasonal":seasonal,"residual":residual})
plt.figure(figsize=(16,8))

plt.subplot(411)
sns.lineplot(x=df_res.index, y='observed', data=df_res, color ='green')
plt.title('Soybeans')
plt.tick_params(axis='y', which='both', bottom=False, top=False, labelleft=False)

plt.subplot(412)
sns.lineplot(x=df_res.index, y='trend', data=df_res, color ='green')
plt.tick_params(axis='y', which='both', bottom=False, top=False, labelleft=False)

plt.subplot(413)
sns.lineplot(x=df_res.index, y='seasonal', data=df_res, color ='green')
plt.tick_params(axis='y', which='both', bottom=False, top=False, labelleft=False)

plt.subplot(414)
sns.lineplot(x=df_res.index, y='residual', data=df_res, color ='green')
plt.tick_params(axis='y', which='both', bottom=False, top=False, labelleft=False)
plt.hlines(y=0,xmin=df_res.index.min(), xmax=df_res.index.max())
plt.show()

# %%
model = Prophet()
model.fit(df_soybeans)
future = model.make_future_dataframe(periods=11, freq='Y')
forecast_soybeans = model.predict(future)
forecast_plot = model.plot(forecast_soybeans)
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 17.

# %%
forecast_soybeans
# Out:
#            ds         trend    yhat_lower    yhat_upper   trend_lower  \
# 0  1997-01-01 -7.145375e+14 -4.734487e+15  5.553433e+14 -7.145375e+14
# 1  1998-01-01 -4.732791e+13 -4.873434e+15  6.909480e+14 -4.732791e+13
# 2  1999-01-01  6.198816e+14 -4.544154e+15  8.401904e+14  6.198816e+14
# 3  2000-01-01  1.287091e+15 -4.641259e+15  6.783920e+14  1.287091e+15
# 4  2001-01-01  1.956129e+15 -1.898412e+15  3.387544e+15  1.956129e+15
# 5  2002-01-01  2.623338e+15 -1.845161e+15  3.428477e+15  2.623338e+15
# 6  2003-01-01  3.290548e+15 -2.073942e+15  3.398695e+15  3.290548e+15
# 7  2004-01-01  3.957757e+15 -2.042721e+15  3.358762e+15  3.957757e+15
# 8  2005-01-01  4.626795e+15  6.202357e+14  5.792593e+15  4.626795e+15
# 9  2006-01-01  5.294004e+15  7.552164e+14  5.916923e+15  5.294004e+15
# 10 2007-01-01  5.961214e+15  4.886646e+14  5.811978e+15  5.961214e+15
# 11 2008-01-01  6.628424e+15  7.245122e+14  6.090485e+15  6.628424e+15
# 12 2009-01-01  7.297461e+15  3.417888e+15  8.601007e+15  7.297461e+15
# 13 2010-01-01  7.964671e+15  3.231939e+15  8.508789e+15  7.964671e+15
# 14 2011-01-01  8.631943e+15  3.274853e+15  8.848581e+15  8.631943e+15
# 15 2012-01-01  9.299246e+15  3.334036e+15  8.887627e+15  9.299246e+15
# 16 2013-01-01  9.968377e+15  6.028960e+15  1.130435e+16  9.968377e+15
# 17 2014-01-01  1.063568e+16  5.936725e+15  1.128038e+16  1.063568e+16
#
#           yearly  yearly_lower  yearly_upper  multiplicative_terms  \
# 0  -1.320775e+15 -1.320775e+15 -1.320775e+15                   0.0
# 1  -1.956388e+15 -1.956388e+15 -1.956388e+15                   0.0
# 2  -2.603711e+15 -2.603711e+15 -2.603711e+15                   0.0
# 3  -3.261946e+15 -3.261946e+15 -3.261946e+15                   0.0
# 4  -1.320775e+15 -1.320775e+15 -1.320775e+15                   0.0
# 5  -1.956388e+15 -1.956388e+15 -1.956388e+15                   0.0
# 6  -2.603711e+15 -2.603711e+15 -2.603711e+15                   0.0
# 7  -3.261946e+15 -3.261946e+15 -3.261946e+15                   0.0
# 8  -1.320775e+15 -1.320775e+15 -1.320775e+15                   0.0
# 9  -1.956388e+15 -1.956388e+15 -1.956388e+15                   0.0
# 10 -2.603711e+15 -2.603711e+15 -2.603711e+15                   0.0
# 11 -3.261946e+15 -3.261946e+15 -3.261946e+15                   0.0
# 12 -1.320775e+15 -1.320775e+15 -1.320775e+15                   0.0
# 13 -1.956388e+15 -1.956388e+15 -1.956388e+15                   0.0
# 14 -2.603711e+15 -2.603711e+15 -2.603711e+15                   0.0
# 15 -3.261946e+15 -3.261946e+15 -3.261946e+15                   0.0
# 16 -1.320775e+15 -1.320775e+15 -1.320775e+15                   0.0
# 17 -1.956388e+15 -1.956388e+15 -1.956388e+15                   0.0
# 18 -2.603711e+15 -2.603711e+15 -2.603711e+15                   0.0
# 19 -3.261946e+15 -3.261946e+15 -3.261946e+15                   0.0
# 20 -1.320775e+15 -1.320775e+15 -1.320775e+15                   0.0
# 21 -1.956388e+15 -1.956388e+15 -1.956388e+15                   0.0
# 22 -2.603711e+15 -2.603711e+15 -2.603711e+15                   0.0
# 23 -5.987373e+15 -5.987373e+15 -5.987373e+15                   0.0
# 24 -3.930276e+15 -3.930276e+15 -3.930276e+15                   0.0
# 25 -4.607863e+15 -4.607863e+15 -4.607863e+15                   0.0
# 26 -5.293852e+15 -5.293852e+15 -5.293852e+15                   0.0
# 27 -5.987373e+15 -5.987373e+15 -5.987373e+15                   0.0
# 28 -3.930276e+15 -3.930276e+15 -3.930276e+15                   0.0
# 29 -4.607863e+15 -4.607863e+15 -4.607863e+15                   0.0
# 30 -5.293852e+15 -5.293852e+15 -5.293852e+15                   0.0
# 31 -5.987373e+15 -5.987373e+15 -5.987373e+15                   0.0
# 32 -3.930276e+15 -3.930276e+15 -3.930276e+15                   0.0
# 33 -4.607863e+15 -4.607863e+15 -4.607863e+15                   0.0
#
#     multiplicative_terms_lower  multiplicative_terms_upper          yhat
# 0                          0.0                         0.0 -2.035313e+15
# 1                          0.0                         0.0 -2.003716e+15
# 2                          0.0                         0.0 -1.983829e+15
# 3                          0.0                         0.0 -1.974855e+15
# 4                          0.0                         0.0  6.353533e+14
# 5                          0.0                         0.0  6.669502e+14
# 6                          0.0                         0.0  6.868370e+14
# 7                          0.0                         0.0  6.958114e+14
# 8                          0.0                         0.0  3.306019e+15
# 9                          0.0                         0.0  3.337616e+15
# 10                         0.0                         0.0  3.357503e+15
# 11                         0.0                         0.0  3.366478e+15
# 12                         0.0                         0.0  5.976686e+15
# 13                         0.0                         0.0  6.008283e+15
# 14                         0.0                         0.0  6.028232e+15
# 15                         0.0                         0.0  6.037300e+15
# 16                         0.0                         0.0  8.647601e+15
# 17                         0.0                         0.0  8.679292e+15
# 18                         0.0                         0.0  8.699272e+15
# 19                         0.0                         0.0  8.708340e+15
# 20                         0.0                         0.0  1.131864e+16
# 21                         0.0                         0.0  1.135033e+16
# 22                         0.0                         0.0  1.137031e+16
# 23                         0.0                         0.0  8.652125e+15
# 24                         0.0                         0.0  1.137835e+16
# 25                         0.0                         0.0  1.136807e+16
# 26                         0.0                         0.0  1.134938e+16
# 27                         0.0                         0.0  1.132317e+16
# 28                         0.0                         0.0  1.404939e+16
# 29                         0.0                         0.0  1.403911e+16
# 30                         0.0                         0.0  1.402042e+16
# 31                         0.0                         0.0  1.399421e+16
# 32                         0.0                         0.0  1.672043e+16
# 33                         0.0                         0.0  1.671015e+16

# %% [markdown]
# ### Farinha de soja
