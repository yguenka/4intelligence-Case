# %% [markdown]
# # Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
import statsmodels.api as sm
from fbprophet import Prophet
from pandas.plotting import lag_plot
import seaborn as sns
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.stattools import adfuller
# Out:
# Importing plotly failed. Interactive plots will not work.

# %% [markdown]
# # Case 1

# %%
df = pd.read_csv('TFP.csv')

# %%
df
# Out:
#     isocode  year    rtfpna
# 0       USA  1950  0.617148
# 1       USA  1951  0.629588
# 2       USA  1952  0.638451
# 3       USA  1953  0.651858
# 4       USA  1954  0.646179
# ..      ...   ...       ...
# 181     MEX  2007  1.013673
# 182     MEX  2008  0.991548
# 183     MEX  2009  0.915879
# 184     MEX  2010  0.941604
# 185     MEX  2011  0.955766
#
# [186 rows x 3 columns]

# %%
mask1 = df['isocode'] == 'USA'
mask2 = df['isocode'] == 'CAN'
mask3 = df['isocode'] == 'MEX'

# %%
df_usa = df[mask1].drop(columns=['isocode'])
df_can = df[mask2].drop(columns=['isocode'])
df_mex = df[mask3].drop(columns=['isocode'])

# %%
plt.plot(df_usa['year'], df_usa['rtfpna'], 'r-', df_can['year'], df_can['rtfpna'], 'blue', df_mex['year'], df_mex['rtfpna'], 'green')
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.distplot(df_usa['rtfpna'], color='red',label='USA')
sns.distplot(df_can['rtfpna'], color='blue',label='CAN')
sns.distplot(df_mex['rtfpna'], color='green',label='MEX')
plt.legend()
plt.title('Frequency distribution')
#plt.tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)
plt.show()

# %% [markdown]
# ## Forecast

# %%
df_usa = df_usa.rename({'year':'ds','rtfpna':'y'},axis=1)
df_can = df_can.rename({'year':'ds','rtfpna':'y'},axis=1)
df_mex = df_mex.rename({'year':'ds','rtfpna':'y'},axis=1)

# %%
df_usa.ds = pd.to_datetime(df_usa.ds, format='%Y')
df_can.ds = pd.to_datetime(df_can.ds, format='%Y')
df_mex.ds = pd.to_datetime(df_mex.ds, format='%Y')

# %%
fig, ax = plt.subplots(1, 3, figsize=(12,4))
lag_plot(df_usa['y'], c='red', ax = ax[0])
lag_plot(df_can['y'], c='blue', ax = ax[1])
lag_plot(df_mex['y'], c='green', ax = ax[2])

# %% [markdown]
# No lag plot, podemos verificar se existe uma relação entre o período anterior com o período seguinte.
#
# Podemos dizer que nos USA existe uma forte relação entre o período anterior com o período seguinte mais forte do que os demais países que estamos analisando.

# %% [markdown]
# ### USA

# %%
fig, ax = plt.subplots(2, 1,figsize=(12,8))
plot_acf(x=df_usa.y, ax=ax[0])
plot_pacf(x=df_usa.y, ax=ax[1]);

# %% [markdown]
# Decomposing a time series into:
#
# - Mean
# - Trends
# - Seasonal Effects
# - Noise

# %%
res = sm.tsa.seasonal_decompose(df_usa['y'], period=6)
observed = res.observed
seasonal = res.seasonal
residual = res.resid
trend = res.trend

# %%
df_res = pd.DataFrame({"observed":observed,"trend":trend, "seasonal":seasonal,"residual":residual})
plt.figure(figsize=(16,8))

plt.subplot(411)
sns.lineplot(x=df_res.index, y='observed', data=df_res, color ='red')
plt.title('USA')
plt.tick_params(axis='y', which='both', bottom=False, top=False, labelleft=False)

plt.subplot(412)
sns.lineplot(x=df_res.index, y='trend', data=df_res, color ='red')
plt.tick_params(axis='y', which='both', bottom=False, top=False, labelleft=False)

plt.subplot(413)
sns.lineplot(x=df_res.index, y='seasonal', data=df_res, color ='red')
plt.tick_params(axis='y', which='both', bottom=False, top=False, labelleft=False)

plt.subplot(414)
sns.lineplot(x=df_res.index, y='residual', data=df_res, color ='red')
plt.tick_params(axis='y', which='both', bottom=False, top=False, labelleft=False)
plt.hlines(y=0,xmin=df_res.index.min(), xmax=df_res.index.max())
plt.show()

# %%
adfuller(df_usa['y'], autolag='AIC', regression='ct')
# Out:
# (-1.4149604461402028,
#  0.856467046010545,
#  0,
#  61,
#  {'1%': -4.115412397821844,
#   '5%': -3.485092052154145,
#   '10%': -3.170590307779065},
#  -302.65363491879026)

# %% [markdown]
# - p-value (neste não pode rejeitar que a times series é estacionária) #ver isso
# -

# %%
model = Prophet(changepoint_range=1)
model.fit(df_usa.iloc[30:,:])
future = model.make_future_dataframe(periods=10,freq='Y')
forecast = model.predict(future)
forecast_plot = model.plot(forecast)
#components_plot_forecast = model.plot_components(forecast)
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
forecast
# Out:
#            ds     trend  yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 0  1980-01-01  0.147045    0.738172    0.760009     0.147045     0.147045
# 1  1981-01-01  0.155679    0.743467    0.764590     0.155679     0.155679
# 2  1982-01-01  0.164290    0.751699    0.772283     0.164290     0.164290
# 3  1983-01-01  0.172901    0.761339    0.781779     0.172901     0.172901
# 4  1984-01-01  0.181512    0.773638    0.792923     0.181512     0.181512
# 5  1985-01-01  0.190146    0.779499    0.799641     0.190146     0.190146
# 6  1986-01-01  0.198742    0.786537    0.806840     0.198742     0.198742
# 7  1987-01-01  0.207337    0.795723    0.816208     0.207337     0.207337
# 8  1988-01-01  0.215931    0.806419    0.827550     0.215931     0.215931
# 9  1989-01-01  0.224549    0.813486    0.833981     0.224549     0.224549
# 10 1990-01-01  0.233143    0.820971    0.840957     0.233143     0.233143
# 11 1991-01-01  0.241737    0.829922    0.851172     0.241737     0.241737
# 12 1992-01-01  0.250339    0.842103    0.862193     0.250339     0.250339
# 13 1993-01-01  0.258984    0.848504    0.867633     0.258984     0.258984
# 14 1994-01-01  0.267605    0.855012    0.875364     0.267605     0.267605
# 15 1995-01-01  0.279213    0.867117    0.888040     0.279213     0.279213
# 16 1996-01-01  0.292515    0.883745    0.904234     0.292515     0.292515
# 17 1997-01-01  0.305857    0.894415    0.915742     0.305857     0.305857
# 18 1998-01-01  0.319162    0.906764    0.927182     0.319162     0.319162
# 19 1999-01-01  0.332466    0.919981    0.940719     0.332466     0.332466
# 20 2000-01-01  0.345769    0.937582    0.957760     0.345769     0.345769
# 21 2001-01-01  0.359101    0.947970    0.968641     0.359101     0.359101
# 22 2002-01-01  0.369119    0.956044    0.976779     0.369119     0.369119
# 23 2003-01-01  0.379098    0.967260    0.987812     0.379098     0.379098
# 24 2004-01-01  0.389076    0.980025    1.001207     0.389076     0.389076
# 25 2005-01-01  0.394674    0.982867    1.003413     0.394674     0.394674
# 26 2006-01-01  0.398018    0.985230    1.006074     0.398018     0.398018
# 27 2007-01-01  0.401354    0.989723    1.010078     0.401354     0.401354
# 28 2008-01-01  0.404690    0.996026    1.017044     0.404690     0.404690
